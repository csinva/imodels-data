# %%
from imodels import FIGSClassifier, get_clean_dataset
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# prepare data (in this a sample clinical dataset)
X, y, feat_names = get_clean_dataset('csi_pecarn_pred')
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# fit the model
model = FIGSClassifier(max_rules=4)  # initialize a model
model.fit(X_train, y_train, feat_names)   # fit model
preds = model.predict(X_test) # discrete predictions: shape is (n_test, 1)
preds_proba = model.predict_proba(X_test) # predicted probabilities: shape is (n_test, n_classes)
print('acc', np.mean(model.predict(X_test) == y_test).round(2))

# visualize the model
print(model)
model.plot(feature_names=feat_names)
# Out:
# acc 0.84
# > ------------------------------
# > FIGS-Fast Interpretable Greedy-Tree Sums:
# > 	Predictions are made by summing the "Val" reached by traversing each tree
# > ------------------------------
# FocalNeuroFindings2 <= 0.500 (Tree #0 root)
# 	AlteredMentalStatus2 <= 0.500 (split)
# 		Val: 0.091 (leaf)
# 		Val: 0.195 (leaf)
# 	Val: 0.426 (leaf)
#
# 	+
# HighriskDiving <= 0.500 (Tree #1 root)
# 	Torticollis2 <= 0.500 (split)
# 		Val: -0.020 (leaf)
# 		Val: 0.190 (leaf)
# 	Val: 0.541 (leaf)

# %% [markdown]
# Now, try without th `max_rules` parameter

# %%
# fit the model
model = FIGSClassifier()  # initialize a model
model.fit(X_train, y_train, feat_names)   # fit model
preds = model.predict(X_test) # discrete predictions: shape is (n_test, 1)
preds_proba = model.predict_proba(X_test) # predicted probabilities: shape is (n_test, n_classes)

# visualize the model
print(model)
model.plot(feature_names=feat_names)
# Out:
# > ------------------------------
# > FIGS-Fast Interpretable Greedy-Tree Sums:
# > 	Predictions are made by summing the "Val" reached by traversing each tree
# > ------------------------------
# FocalNeuroFindings2 <= 0.500 (Tree #0 root)
# 	AlteredMentalStatus2 <= 0.500 (split)
# 		PainNeck2 <= 0.500 (split)
# 			Val: 0.040 (leaf)
# 			Val: 0.157 (leaf)
# 		HighriskMVC <= 0.500 (split)
# 			Val: 0.145 (leaf)
# 			AgeInYears <= 4.055 (split)
# 				Val: 0.618 (leaf)
# 				Val: 0.303 (leaf)
# 	ambulatory <= 0.500 (split)
# 		Val: 0.455 (leaf)
# 		gender_F <= 0.500 (split)
# 			Val: 0.364 (leaf)
# 			Val: 0.037 (leaf)
#
# 	+
# HighriskDiving <= 0.500 (Tree #1 root)
# 	Torticollis2 <= 0.500 (split)
# 		IsEms <= 0.500 (split)
# 			Val: 0.040 (leaf)
# 			SubInjTorsoTrunk2 <= 0.500 (split)
# 				Val: -0.047 (leaf)
# 				Val: 0.085 (leaf)
# 		AgeInYears <= 8.160 (split)
# 			Val: 0.312 (leaf)
# 			Val: 0.026 (leaf)
# 	Val: 0.541 (leaf)
